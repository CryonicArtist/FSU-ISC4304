# %%
n = list
n = [1,4,16,32]

niter = iter(n)

for ni in niter:
    print(ni)
# Out:
# 1
# 4
# 16
# 32

# %%
def zrange(n):
    i = 0
    while i < n:
        yield(i)
        i += 1

# %%
for i in zrange(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
def integers():
    i = 0
    while True:
        print('before yield increases')

# %%
a = (x*x for x in range(10))
a
sum(a)
# Out:
# 285
